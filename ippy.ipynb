# %%
import pandas as pd
import matplotlib.pyplot as plt

Porsche_file_path = '/content/Porsche_Financials.xlsx'
Ferrari_file_path = '/content/Ferrari_Financials.xlsx'
MercedesBenz_file_path = '/content/MercedesBenz_Financials.xlsx'
Volvo_file_path = '/content/Volvo_Financials.xlsx'

Porsche_sheet1_df = pd.read_excel(Porsche_file_path, sheet_name='Income Statement')
Porsche_sheet1_df.iloc[1:44, 1:5] = Porsche_sheet1_df.iloc[1:44, 1:5].replace('-', 0)
Porsche_sheet2_df = pd.read_excel(Porsche_file_path, sheet_name='Balance Sheet')
Porsche_sheet2_df.iloc[1:56, 1:5] = Porsche_sheet2_df.iloc[1:56, 1:5].replace('-', 0)
Porsche_sheet3_df = pd.read_excel(Porsche_file_path, sheet_name='Cash Flow')
Porsche_sheet3_df.iloc[1:13, 1:5] = Porsche_sheet3_df.iloc[1:13, 1:5].replace('-', 0)

Ferrari_sheet1_df = pd.read_excel(Ferrari_file_path, sheet_name='Income Statement')
Ferrari_sheet1_df.iloc[1:44, 1:5] = Ferrari_sheet1_df.iloc[1:44, 1:5].replace('-', 0)
Ferrari_sheet2_df = pd.read_excel(Ferrari_file_path, sheet_name='Balance Sheet')
Ferrari_sheet2_df.iloc[1:56, 1:5] = Ferrari_sheet2_df.iloc[1:56, 1:5].replace('-', 0)
Ferrari_sheet3_df = pd.read_excel(Ferrari_file_path, sheet_name='Cash Flow')
Ferrari_sheet3_df.iloc[1:13, 1:5] = Ferrari_sheet3_df.iloc[1:13, 1:5].replace('-', 0)

MercedesBenz_sheet1_df = pd.read_excel(MercedesBenz_file_path, sheet_name='Income Statement')
MercedesBenz_sheet1_df.iloc[1:44, 1:5] = MercedesBenz_sheet1_df.iloc[1:44, 1:5].replace('-', 0)
MercedesBenz_sheet2_df = pd.read_excel(MercedesBenz_file_path, sheet_name='Balance Sheet')
MercedesBenz_sheet2_df.iloc[1:56, 1:5] = MercedesBenz_sheet2_df.iloc[1:56, 1:5].replace('-', 0)
MercedesBenz_sheet3_df = pd.read_excel(MercedesBenz_file_path, sheet_name='Cash Flow')
MercedesBenz_sheet3_df.iloc[1:13, 1:5] = MercedesBenz_sheet3_df.iloc[1:13, 1:5].replace('-', 0)

Volvo_sheet1_df = pd.read_excel(Volvo_file_path, sheet_name='Income Statement')
Volvo_sheet1_df.iloc[1:44, 1:5] = Volvo_sheet1_df.iloc[1:44, 1:5].replace('-', 0)
Volvo_sheet2_df = pd.read_excel(Volvo_file_path, sheet_name='Balance Sheet')
Volvo_sheet2_df.iloc[1:56, 1:5] = Volvo_sheet2_df.iloc[1:56, 1:5].replace('-', 0)
Volvo_sheet3_df = pd.read_excel(Volvo_file_path, sheet_name='Cash Flow')
Volvo_sheet3_df.iloc[1:13, 1:5] = Volvo_sheet3_df.iloc[1:13, 1:5].replace('-', 0)

Three_years = ["2021","2022","2023"]
Four_years = ["2020","2021","2022","2023"]

# %%
Porsche_Revenue_Growth_Rate_2023 = 100*(Porsche_sheet1_df.iloc[1, 1] - Porsche_sheet1_df.iloc[1, 2]) / Porsche_sheet1_df.iloc[1, 2]
Porsche_Revenue_Growth_Rate_2022 = 100*(Porsche_sheet1_df.iloc[1, 2] - Porsche_sheet1_df.iloc[1, 3]) / Porsche_sheet1_df.iloc[1, 3]
Porsche_Revenue_Growth_Rate_2021 = 100*(Porsche_sheet1_df.iloc[1, 3] - Porsche_sheet1_df.iloc[1, 4]) / Porsche_sheet1_df.iloc[1, 4]

Porsche_Revenue_Growth_Rate = [Porsche_Revenue_Growth_Rate_2021,Porsche_Revenue_Growth_Rate_2022,Porsche_Revenue_Growth_Rate_2023]
plt.figure(figsize =(8,6))
plt.plot(Three_years,Porsche_Revenue_Growth_Rate, marker='o',color='orange',linestyle='-')
plt.xlabel('Year')
plt.ylabel('Porsche Revenue Growth Rate (%)')
plt.title('Porsche Revenue Growth Rate for Each Year')
plt.show()

Porsche_Net_Profit_Margin_2023 = 100*(Porsche_sheet1_df.iloc[17, 1])/ Porsche_sheet1_df.iloc[1, 1]
Porsche_Net_Profit_Margin_2022 = 100*(Porsche_sheet1_df.iloc[17, 2])/ Porsche_sheet1_df.iloc[1, 2]
Porsche_Net_Profit_Margin_2021 = 100*(Porsche_sheet1_df.iloc[17, 3])/ Porsche_sheet1_df.iloc[1, 3]
Porsche_Net_Profit_Margin_2020 = 100*(Porsche_sheet1_df.iloc[17, 4])/ Porsche_sheet1_df.iloc[1, 4]

Porsche_Net_Profit_Margin = [Porsche_Net_Profit_Margin_2020,Porsche_Net_Profit_Margin_2021,Porsche_Net_Profit_Margin_2022,Porsche_Net_Profit_Margin_2023]
plt.figure(figsize =(8,6))
plt.plot(Four_years,Porsche_Net_Profit_Margin, marker='o',color='orange',linestyle='-')
plt.xlabel('Year')
plt.ylabel('Porsche Net Profit Margin (%)')
plt.title('Porsche Net Profit Margin for Each Year')
plt.show()


Porsche_Current_Ratios_2023 = Porsche_sheet2_df.iloc[2, 1] / Porsche_sheet2_df.iloc[23, 1]
Porsche_Current_Ratios_2022 = Porsche_sheet2_df.iloc[2, 2] / Porsche_sheet2_df.iloc[23, 2]
Porsche_Current_Ratios_2021 = Porsche_sheet2_df.iloc[2, 3] / Porsche_sheet2_df.iloc[23, 3]
Porsche_Current_Ratios_2020 = Porsche_sheet2_df.iloc[2, 4] / Porsche_sheet2_df.iloc[23, 4]

Porsche_Current_Ratios = [Porsche_Current_Ratios_2020,Porsche_Current_Ratios_2021,Porsche_Current_Ratios_2022,Porsche_Current_Ratios_2023]
plt.figure(figsize =(8,6))
plt.plot(Four_years,Porsche_Current_Ratios, marker='o',color='orange',linestyle='-')
plt.xlabel('Year')
plt.ylabel('Porsche Current Ratios')
plt.title('Porsche Current Ratios for Each Year')
plt.show()


Porsche_Quick_Ratio_2023 = (Porsche_sheet2_df.iloc[3, 1]+Porsche_sheet2_df.iloc[4, 1])/Porsche_sheet2_df.iloc[23, 1]
Porsche_Quick_Ratio_2022 = (Porsche_sheet2_df.iloc[3, 2]+Porsche_sheet2_df.iloc[4, 2])/Porsche_sheet2_df.iloc[23, 2]
Porsche_Quick_Ratio_2021 = (Porsche_sheet2_df.iloc[3, 3]+Porsche_sheet2_df.iloc[4, 3])/Porsche_sheet2_df.iloc[23, 3]
Porsche_Quick_Ratio_2020 = (Porsche_sheet2_df.iloc[3, 4]+Porsche_sheet2_df.iloc[4, 4])/Porsche_sheet2_df.iloc[23, 4]

Porsche_Quick_Ratio = [Porsche_Quick_Ratio_2020,Porsche_Quick_Ratio_2021,Porsche_Quick_Ratio_2022,Porsche_Quick_Ratio_2023]
plt.figure(figsize =(8,6))
plt.plot(Four_years,Porsche_Quick_Ratio, marker='o',color='orange',linestyle='-')
plt.xlabel('Year')
plt.ylabel('Porsche Quick Ratio')
plt.title('Porsche Quick Ratio for Each Year')
plt.show()


Porsche_Debt_To_Equity_Ratio_2023 = Porsche_sheet2_df.iloc[52, 1] / Porsche_sheet2_df.iloc[38, 1]
Porsche_Debt_To_Equity_Ratio_2022 = Porsche_sheet2_df.iloc[52, 2] / Porsche_sheet2_df.iloc[38, 2]
Porsche_Debt_To_Equity_Ratio_2021 = Porsche_sheet2_df.iloc[52, 3] / Porsche_sheet2_df.iloc[38, 3]
Porsche_Debt_To_Equity_Ratio_2020 = Porsche_sheet2_df.iloc[52, 4] / Porsche_sheet2_df.iloc[38, 4]

Porsche_Debt_To_Equity_Ratio = [Porsche_Debt_To_Equity_Ratio_2020,Porsche_Debt_To_Equity_Ratio_2021,Porsche_Debt_To_Equity_Ratio_2022,Porsche_Debt_To_Equity_Ratio_2023]
plt.figure(figsize =(8,6))
plt.plot(Four_years,Porsche_Debt_To_Equity_Ratio, marker='o',color='orange',linestyle='-')
plt.xlabel('Year')
plt.ylabel('Porsche Debt To Equity Ratio')
plt.title('Porsche Debt To Equity Ratio for Each Year')
plt.show()

Porsche_Operating_Cash_Flow_Ratio_2023 = Porsche_sheet3_df.iloc[1, 1]/Porsche_sheet2_df.iloc[23, 1]
Porsche_Operating_Cash_Flow_Ratio_2022 = Porsche_sheet3_df.iloc[1, 2]/Porsche_sheet2_df.iloc[23, 2]
Porsche_Operating_Cash_Flow_Ratio_2021 = Porsche_sheet3_df.iloc[1, 3]/Porsche_sheet2_df.iloc[23, 3]
Porsche_Operating_Cash_Flow_Ratio_2020 = Porsche_sheet3_df.iloc[1, 4]/Porsche_sheet2_df.iloc[23, 4]

Porsche_Operating_Cash_Flow_Ratio = [Porsche_Operating_Cash_Flow_Ratio_2020,Porsche_Operating_Cash_Flow_Ratio_2021,Porsche_Operating_Cash_Flow_Ratio_2022,Porsche_Operating_Cash_Flow_Ratio_2023]
plt.figure(figsize =(8,6))
plt.plot(Four_years,Porsche_Operating_Cash_Flow_Ratio, marker='o',color='orange',linestyle='-')
plt.xlabel('Year')
plt.ylabel('Porsche Operating Cash Flow Ratio')
plt.title('Porsche Operating Cash Flow Ratio for Each Year')
plt.show()

Porsche_Free_Cash_Flow_2023 = Porsche_sheet3_df.iloc[1, 1] - Porsche_sheet3_df.iloc[9, 1]
Porsche_Free_Cash_Flow_2022 = Porsche_sheet3_df.iloc[1, 2] - Porsche_sheet3_df.iloc[9, 2]
Porsche_Free_Cash_Flow_2021 = Porsche_sheet3_df.iloc[1, 3] - Porsche_sheet3_df.iloc[9, 3]
Porsche_Free_Cash_Flow_2020 = Porsche_sheet3_df.iloc[1, 4] - Porsche_sheet3_df.iloc[9, 4]

Porsche_Free_Cash_Flow = [Porsche_Free_Cash_Flow_2020,Porsche_Free_Cash_Flow_2021,Porsche_Free_Cash_Flow_2022,Porsche_Free_Cash_Flow_2023]
plt.figure(figsize =(8,6))
plt.plot(Four_years,Porsche_Free_Cash_Flow, marker='o',color='orange',linestyle='-')
plt.xlabel('Year')
plt.ylabel('Porsche Free Cash Flow')
plt.title('Porsche Free Cash Flow for Each Year')
plt.show()
# Out:
# [75.28387585162756, 17.469229108183978, 0.12867647058823528]
# [99.28084784254352, 98.59641546102354, 100.95588235294117, 93.55608591885442]
# [6.066666666666666, 6.442953020134228, 0.19092959158105738, 7.518248175182482]
# [8.209523809523809, 6.12751677852349, 0.13329992483086944, 11.014598540145986]
# [0.001057170677423842, 0.0, 0.060453786992462455, 0.12153417922857246]
# [7.3619047619047615, 4.919463087248322, 0.19819594086695064, 13.671532846715328]
# [775000, 733000, 791000, 1873000]

# %%
# Revenue Growth Rate
Ferrari_Revenue_Growth_Rate_2023 = 100*(Ferrari_sheet1_df.iloc[1, 1] - Ferrari_sheet1_df.iloc[1, 2]) / Ferrari_sheet1_df.iloc[1, 2]
Ferrari_Revenue_Growth_Rate_2022 = 100*(Ferrari_sheet1_df.iloc[1, 2] - Ferrari_sheet1_df.iloc[1, 3]) / Ferrari_sheet1_df.iloc[1, 3]
Ferrari_Revenue_Growth_Rate_2021 = 100*(Ferrari_sheet1_df.iloc[1, 3] - Ferrari_sheet1_df.iloc[1, 4]) / Ferrari_sheet1_df.iloc[1, 4]

Ferrari_Revenue_Growth_Rate = [Ferrari_Revenue_Growth_Rate_2021, Ferrari_Revenue_Growth_Rate_2022, Ferrari_Revenue_Growth_Rate_2023]
print(Ferrari_Revenue_Growth_Rate)
plt.figure(figsize=(8,6))
plt.plot(Three_years, Ferrari_Revenue_Growth_Rate, marker='o', color='red', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Ferrari Revenue Growth Rate (%)')
plt.title('Ferrari Revenue Growth Rate for Each Year')
plt.show()

# Net Profit Margin
Ferrari_Net_Profit_Margin_2023 = 100*(Ferrari_sheet1_df.iloc[17, 1])/ Ferrari_sheet1_df.iloc[1, 1]
Ferrari_Net_Profit_Margin_2022 = 100*(Ferrari_sheet1_df.iloc[17, 2])/ Ferrari_sheet1_df.iloc[1, 2]
Ferrari_Net_Profit_Margin_2021 = 100*(Ferrari_sheet1_df.iloc[17, 3])/ Ferrari_sheet1_df.iloc[1, 3]
Ferrari_Net_Profit_Margin_2020 = 100*(Ferrari_sheet1_df.iloc[17, 4])/ Ferrari_sheet1_df.iloc[1, 4]

Ferrari_Net_Profit_Margin = [Ferrari_Net_Profit_Margin_2020, Ferrari_Net_Profit_Margin_2021, Ferrari_Net_Profit_Margin_2022, Ferrari_Net_Profit_Margin_2023]
print(Ferrari_Net_Profit_Margin)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Ferrari_Net_Profit_Margin, marker='o', color='red', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Ferrari Net Profit Margin (%)')
plt.title('Ferrari Net Profit Margin for Each Year')
plt.show()

# Current Ratios
Ferrari_Current_Ratios_2023 = Ferrari_sheet2_df.iloc[2, 1] / Ferrari_sheet2_df.iloc[23, 1]
Ferrari_Current_Ratios_2022 = Ferrari_sheet2_df.iloc[2, 2] / Ferrari_sheet2_df.iloc[23, 2]
Ferrari_Current_Ratios_2021 = Ferrari_sheet2_df.iloc[2, 3] / Ferrari_sheet2_df.iloc[23, 3]
Ferrari_Current_Ratios_2020 = Ferrari_sheet2_df.iloc[2, 4] / Ferrari_sheet2_df.iloc[23, 4]

Ferrari_Current_Ratios = [Ferrari_Current_Ratios_2020, Ferrari_Current_Ratios_2021, Ferrari_Current_Ratios_2022, Ferrari_Current_Ratios_2023]
print(Ferrari_Current_Ratios)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Ferrari_Current_Ratios, marker='o', color='red', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Ferrari Current Ratios')
plt.title('Ferrari Current Ratios for Each Year')
plt.show()

# Quick Ratios
Ferrari_Quick_Ratio_2023 = (Ferrari_sheet2_df.iloc[3, 1]+Ferrari_sheet2_df.iloc[4, 1])/Ferrari_sheet2_df.iloc[23, 1]
Ferrari_Quick_Ratio_2022 = (Ferrari_sheet2_df.iloc[3, 2]+Ferrari_sheet2_df.iloc[4, 2])/Ferrari_sheet2_df.iloc[23, 2]
Ferrari_Quick_Ratio_2021 = (Ferrari_sheet2_df.iloc[3, 3]+Ferrari_sheet2_df.iloc[4, 3])/Ferrari_sheet2_df.iloc[23, 3]
Ferrari_Quick_Ratio_2020 = (Ferrari_sheet2_df.iloc[3, 4]+Ferrari_sheet2_df.iloc[4, 4])/Ferrari_sheet2_df.iloc[23, 4]

Ferrari_Quick_Ratio = [Ferrari_Quick_Ratio_2020, Ferrari_Quick_Ratio_2021, Ferrari_Quick_Ratio_2022, Ferrari_Quick_Ratio_2023]
print(Ferrari_Quick_Ratio)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Ferrari_Quick_Ratio, marker='o', color='red', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Ferrari Quick Ratio')
plt.title('Ferrari Quick Ratio for Each Year')
plt.show()

# Debt to Equity Ratio
Ferrari_Debt_To_Equity_Ratio_2023 = Ferrari_sheet2_df.iloc[52, 1] / Ferrari_sheet2_df.iloc[38, 1]
Ferrari_Debt_To_Equity_Ratio_2022 = Ferrari_sheet2_df.iloc[52, 2] / Ferrari_sheet2_df.iloc[38, 2]
Ferrari_Debt_To_Equity_Ratio_2021 = Ferrari_sheet2_df.iloc[52, 3] / Ferrari_sheet2_df.iloc[38, 3]
Ferrari_Debt_To_Equity_Ratio_2020 = Ferrari_sheet2_df.iloc[52, 4] / Ferrari_sheet2_df.iloc[38, 4]

Ferrari_Debt_To_Equity_Ratio = [Ferrari_Debt_To_Equity_Ratio_2020, Ferrari_Debt_To_Equity_Ratio_2021, Ferrari_Debt_To_Equity_Ratio_2022, Ferrari_Debt_To_Equity_Ratio_2023]
print(Ferrari_Debt_To_Equity_Ratio)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Ferrari_Debt_To_Equity_Ratio, marker='o', color='red', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Ferrari Debt To Equity Ratio')
plt.title('Ferrari Debt To Equity Ratio for Each Year')
plt.show()

# Operating Cash Flow Ratio
Ferrari_Operating_Cash_Flow_Ratio_2023 = Ferrari_sheet3_df.iloc[1, 1]/Ferrari_sheet2_df.iloc[23, 1]
Ferrari_Operating_Cash_Flow_Ratio_2022 = Ferrari_sheet3_df.iloc[1, 2]/Ferrari_sheet2_df.iloc[23, 2]
Ferrari_Operating_Cash_Flow_Ratio_2021 = Ferrari_sheet3_df.iloc[1, 3]/Ferrari_sheet2_df.iloc[23, 3]
Ferrari_Operating_Cash_Flow_Ratio_2020 = Ferrari_sheet3_df.iloc[1, 4]/Ferrari_sheet2_df.iloc[23, 4]

Ferrari_Operating_Cash_Flow_Ratio = [Ferrari_Operating_Cash_Flow_Ratio_2020, Ferrari_Operating_Cash_Flow_Ratio_2021, Ferrari_Operating_Cash_Flow_Ratio_2022, Ferrari_Operating_Cash_Flow_Ratio_2023]
print(Ferrari_Operating_Cash_Flow_Ratio)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Ferrari_Operating_Cash_Flow_Ratio, marker='o', color='red', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Ferrari Operating Cash Flow Ratio')
plt.title('Ferrari Operating Cash Flow Ratio for Each Year')
plt.show()

# Free Cash Flow
Ferrari_Free_Cash_Flow_2023 = Ferrari_sheet3_df.iloc[1, 1] - Ferrari_sheet3_df.iloc[9, 1]
Ferrari_Free_Cash_Flow_2022 = Ferrari_sheet3_df.iloc[1, 2] - Ferrari_sheet3_df.iloc[9, 2]
Ferrari_Free_Cash_Flow_2021 = Ferrari_sheet3_df.iloc[1, 3] - Ferrari_sheet3_df.iloc[9, 3]
Ferrari_Free_Cash_Flow_2020 = Ferrari_sheet3_df.iloc[1, 4] - Ferrari_sheet3_df.iloc[9, 4]

Ferrari_Free_Cash_Flow = [Ferrari_Free_Cash_Flow_2020, Ferrari_Free_Cash_Flow_2021, Ferrari_Free_Cash_Flow_2022, Ferrari_Free_Cash_Flow_2023]
print(Ferrari_Free_Cash_Flow)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Ferrari_Free_Cash_Flow, marker='o', color='red', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Ferrari Free Cash Flow')
plt.title('Ferrari Free Cash Flow for Each Year')
plt.show()
# Out:
# [23.443735024380093, 19.301813624969387, 17.170723971758818]
# [-0.39967743706987996, -0.10562191428773461, -0.38757636027566045, -0.23550512835029494]
# [104.65390765880711, 67.19911698897235, 29.945541328888552, 26.357424832538733]
# [92.75832737912967, 53.74434633210804, 21.09909841654671, 14.874990907828526]
# [0.060548961812431155, 0.05507332297382961, 0.052360140808190674, 0.05936587099377797]
# [28.519308631894116, 25.62581908262746, 10.63216910371998, 11.3512421559357]
# [411574, 826737, 857115, 1054332]

# %%
# Revenue Growth Rate
MercedesBenz_Revenue_Growth_Rate_2023 = 100*(MercedesBenz_sheet1_df.iloc[1, 1] - MercedesBenz_sheet1_df.iloc[1, 2]) / MercedesBenz_sheet1_df.iloc[1, 2]
MercedesBenz_Revenue_Growth_Rate_2022 = 100*(MercedesBenz_sheet1_df.iloc[1, 2] - MercedesBenz_sheet1_df.iloc[1, 3]) / MercedesBenz_sheet1_df.iloc[1, 3]
MercedesBenz_Revenue_Growth_Rate_2021 = 100*(MercedesBenz_sheet1_df.iloc[1, 3] - MercedesBenz_sheet1_df.iloc[1, 4]) / MercedesBenz_sheet1_df.iloc[1, 4]

MercedesBenz_Revenue_Growth_Rate = [MercedesBenz_Revenue_Growth_Rate_2021, MercedesBenz_Revenue_Growth_Rate_2022, MercedesBenz_Revenue_Growth_Rate_2023]
print(MercedesBenz_Revenue_Growth_Rate)
plt.figure(figsize=(8,6))
plt.plot(Three_years, MercedesBenz_Revenue_Growth_Rate, marker='o', color='blue', linestyle='-')
plt.xlabel('Year')
plt.ylabel('MercedesBenz Revenue Growth Rate (%)')
plt.title('MercedesBenz Revenue Growth Rate for Each Year')
plt.show()

# Net Profit Margin
MercedesBenz_Net_Profit_Margin_2023 = 100*(MercedesBenz_sheet1_df.iloc[17, 1])/ MercedesBenz_sheet1_df.iloc[1, 1]
MercedesBenz_Net_Profit_Margin_2022 = 100*(MercedesBenz_sheet1_df.iloc[17, 2])/ MercedesBenz_sheet1_df.iloc[1, 2]
MercedesBenz_Net_Profit_Margin_2021 = 100*(MercedesBenz_sheet1_df.iloc[17, 3])/ MercedesBenz_sheet1_df.iloc[1, 3]
MercedesBenz_Net_Profit_Margin_2020 = 100*(MercedesBenz_sheet1_df.iloc[17, 4])/ MercedesBenz_sheet1_df.iloc[1, 4]

MercedesBenz_Net_Profit_Margin = [MercedesBenz_Net_Profit_Margin_2020, MercedesBenz_Net_Profit_Margin_2021, MercedesBenz_Net_Profit_Margin_2022, MercedesBenz_Net_Profit_Margin_2023]
print(MercedesBenz_Net_Profit_Margin)
plt.figure(figsize=(8,6))
plt.plot(Four_years, MercedesBenz_Net_Profit_Margin, marker='o', color='blue', linestyle='-')
plt.xlabel('Year')
plt.ylabel('MercedesBenz Net Profit Margin (%)')
plt.title('MercedesBenz Net Profit Margin for Each Year')
plt.show()

# Current Ratios
MercedesBenz_Current_Ratios_2023 = MercedesBenz_sheet2_df.iloc[2, 1] / MercedesBenz_sheet2_df.iloc[23, 1]
MercedesBenz_Current_Ratios_2022 = MercedesBenz_sheet2_df.iloc[2, 2] / MercedesBenz_sheet2_df.iloc[23, 2]
MercedesBenz_Current_Ratios_2021 = MercedesBenz_sheet2_df.iloc[2, 3] / MercedesBenz_sheet2_df.iloc[23, 3]
MercedesBenz_Current_Ratios_2020 = MercedesBenz_sheet2_df.iloc[2, 4] / MercedesBenz_sheet2_df.iloc[23, 4]

MercedesBenz_Current_Ratios = [MercedesBenz_Current_Ratios_2020, MercedesBenz_Current_Ratios_2021, MercedesBenz_Current_Ratios_2022, MercedesBenz_Current_Ratios_2023]
print(MercedesBenz_Current_Ratios)
plt.figure(figsize=(8,6))
plt.plot(Four_years, MercedesBenz_Current_Ratios, marker='o', color='blue', linestyle='-')
plt.xlabel('Year')
plt.ylabel('MercedesBenz Current Ratios')
plt.title('MercedesBenz Current Ratios for Each Year')
plt.show()

# Quick Ratios
MercedesBenz_Quick_Ratio_2023 = (MercedesBenz_sheet2_df.iloc[3, 1]+MercedesBenz_sheet2_df.iloc[4, 1])/MercedesBenz_sheet2_df.iloc[23, 1]
MercedesBenz_Quick_Ratio_2022 = (MercedesBenz_sheet2_df.iloc[3, 2]+MercedesBenz_sheet2_df.iloc[4, 2])/MercedesBenz_sheet2_df.iloc[23, 2]
MercedesBenz_Quick_Ratio_2021 = (MercedesBenz_sheet2_df.iloc[3, 3]+MercedesBenz_sheet2_df.iloc[4, 3])/MercedesBenz_sheet2_df.iloc[23, 3]
MercedesBenz_Quick_Ratio_2020 = (MercedesBenz_sheet2_df.iloc[3, 4]+MercedesBenz_sheet2_df.iloc[4, 4])/MercedesBenz_sheet2_df.iloc[23, 4]

MercedesBenz_Quick_Ratio = [MercedesBenz_Quick_Ratio_2020, MercedesBenz_Quick_Ratio_2021, MercedesBenz_Quick_Ratio_2022, MercedesBenz_Quick_Ratio_2023]
print(MercedesBenz_Quick_Ratio)
plt.figure(figsize=(8,6))
plt.plot(Four_years, MercedesBenz_Quick_Ratio, marker='o', color='blue', linestyle='-')
plt.xlabel('Year')
plt.ylabel('MercedesBenz Quick Ratio')
plt.title('MercedesBenz Quick Ratio for Each Year')
plt.show()

# Debt to Equity Ratio
MercedesBenz_Debt_To_Equity_Ratio_2023 = MercedesBenz_sheet2_df.iloc[52, 1] / MercedesBenz_sheet2_df.iloc[38, 1]
MercedesBenz_Debt_To_Equity_Ratio_2022 = MercedesBenz_sheet2_df.iloc[52, 2] / MercedesBenz_sheet2_df.iloc[38, 2]
MercedesBenz_Debt_To_Equity_Ratio_2021 = MercedesBenz_sheet2_df.iloc[52, 3] / MercedesBenz_sheet2_df.iloc[38, 3]
MercedesBenz_Debt_To_Equity_Ratio_2020 = MercedesBenz_sheet2_df.iloc[52, 4] / MercedesBenz_sheet2_df.iloc[38, 4]

MercedesBenz_Debt_To_Equity_Ratio = [MercedesBenz_Debt_To_Equity_Ratio_2020, MercedesBenz_Debt_To_Equity_Ratio_2021, MercedesBenz_Debt_To_Equity_Ratio_2022, MercedesBenz_Debt_To_Equity_Ratio_2023]
print(MercedesBenz_Debt_To_Equity_Ratio)
plt.figure(figsize=(8,6))
plt.plot(Four_years, MercedesBenz_Debt_To_Equity_Ratio, marker='o', color='blue', linestyle='-')
plt.xlabel('Year')
plt.ylabel('MercedesBenz Debt To Equity Ratio')
plt.title('MercedesBenz Debt To Equity Ratio for Each Year')
plt.show()

# Operating Cash Flow Ratio
MercedesBenz_Operating_Cash_Flow_Ratio_2023 = MercedesBenz_sheet3_df.iloc[1, 1]/MercedesBenz_sheet2_df.iloc[23, 1]
MercedesBenz_Operating_Cash_Flow_Ratio_2022 = MercedesBenz_sheet3_df.iloc[1, 2]/MercedesBenz_sheet2_df.iloc[23, 2]
MercedesBenz_Operating_Cash_Flow_Ratio_2021 = MercedesBenz_sheet3_df.iloc[1, 3]/MercedesBenz_sheet2_df.iloc[23, 3]
MercedesBenz_Operating_Cash_Flow_Ratio_2020 = MercedesBenz_sheet3_df.iloc[1, 4]/MercedesBenz_sheet2_df.iloc[23, 4]

MercedesBenz_Operating_Cash_Flow_Ratio = [MercedesBenz_Operating_Cash_Flow_Ratio_2020, MercedesBenz_Operating_Cash_Flow_Ratio_2021, MercedesBenz_Operating_Cash_Flow_Ratio_2022, MercedesBenz_Operating_Cash_Flow_Ratio_2023]
print(MercedesBenz_Operating_Cash_Flow_Ratio)
plt.figure(figsize=(8,6))
plt.plot(Four_years, MercedesBenz_Operating_Cash_Flow_Ratio, marker='o', color='blue', linestyle='-')
plt.xlabel('Year')
plt.ylabel('MercedesBenz Operating Cash Flow Ratio')
plt.title('MercedesBenz Operating Cash Flow Ratio for Each Year')
plt.show()

# Free Cash Flow
MercedesBenz_Free_Cash_Flow_2023 = MercedesBenz_sheet3_df.iloc[1, 1] - MercedesBenz_sheet3_df.iloc[9, 1]
MercedesBenz_Free_Cash_Flow_2022 = MercedesBenz_sheet3_df.iloc[1, 2] - MercedesBenz_sheet3_df.iloc[9, 2]
MercedesBenz_Free_Cash_Flow_2021 = MercedesBenz_sheet3_df.iloc[1, 3] - MercedesBenz_sheet3_df.iloc[9, 3]
MercedesBenz_Free_Cash_Flow_2020 = MercedesBenz_sheet3_df.iloc[1, 4] - MercedesBenz_sheet3_df.iloc[9, 4]

MercedesBenz_Free_Cash_Flow = [MercedesBenz_Free_Cash_Flow_2020, MercedesBenz_Free_Cash_Flow_2021, MercedesBenz_Free_Cash_Flow_2022, MercedesBenz_Free_Cash_Flow_2023]
print(MercedesBenz_Free_Cash_Flow)
plt.figure(figsize=(8,6))
plt.plot(Four_years, MercedesBenz_Free_Cash_Flow, marker='o', color='blue', linestyle='-')
plt.xlabel('Year')
plt.ylabel('MercedesBenz Free Cash Flow')
plt.title('MercedesBenz Free Cash Flow for Each Year')
plt.show()
# Out:
# [9.948430751038776, 12.04245180853368, 2.133758174073605]
# [1.5815664569955163, 3.5558244269678028, 3.662918202603705, 3.624247803782845]
# [-1.6390188410949165, -1.8121302816901408, -1.6738638767308287, -1.6954920303790866]
# [-0.7323000355492357, -0.9328169014084507, -0.6839844449144958, -0.6244499494768408]
# [0.38091041397153946, 0.5649718655608199, 0.7957377280421291, 0.8735131932734813]
# [-0.31755421258442945, -0.4322007042253521, -0.274882441953172, -0.23582906874409204]
# [22301000, 24513000, 16894000, 14470000]

# %%
# Revenue Growth Rate
Volvo_Revenue_Growth_Rate_2023 = 100*(Volvo_sheet1_df.iloc[1, 1] - Volvo_sheet1_df.iloc[1, 2]) / Volvo_sheet1_df.iloc[1, 2]
Volvo_Revenue_Growth_Rate_2022 = 100*(Volvo_sheet1_df.iloc[1, 2] - Volvo_sheet1_df.iloc[1, 3]) / Volvo_sheet1_df.iloc[1, 3]
Volvo_Revenue_Growth_Rate_2021 = 100*(Volvo_sheet1_df.iloc[1, 3] - Volvo_sheet1_df.iloc[1, 4]) / Volvo_sheet1_df.iloc[1, 4]

Volvo_Revenue_Growth_Rate = [Volvo_Revenue_Growth_Rate_2021, Volvo_Revenue_Growth_Rate_2022, Volvo_Revenue_Growth_Rate_2023]
print(Volvo_Revenue_Growth_Rate)
plt.figure(figsize=(8,6))
plt.plot(Three_years, Volvo_Revenue_Growth_Rate, marker='o', color='green', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Volvo Revenue Growth Rate (%)')
plt.title('Volvo Revenue Growth Rate for Each Year')
plt.show()

# Net Profit Margin
Volvo_Net_Profit_Margin_2023 = 100*(Volvo_sheet1_df.iloc[17, 1])/ Volvo_sheet1_df.iloc[1, 1]
Volvo_Net_Profit_Margin_2022 = 100*(Volvo_sheet1_df.iloc[17, 2])/ Volvo_sheet1_df.iloc[1, 2]
Volvo_Net_Profit_Margin_2021 = 100*(Volvo_sheet1_df.iloc[17, 3])/ Volvo_sheet1_df.iloc[1, 3]
Volvo_Net_Profit_Margin_2020 = 100*(Volvo_sheet1_df.iloc[17, 4])/ Volvo_sheet1_df.iloc[1, 4]

Volvo_Net_Profit_Margin = [Volvo_Net_Profit_Margin_2020, Volvo_Net_Profit_Margin_2021, Volvo_Net_Profit_Margin_2022, Volvo_Net_Profit_Margin_2023]
print(Volvo_Net_Profit_Margin)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Volvo_Net_Profit_Margin, marker='o', color='green', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Volvo Net Profit Margin (%)')
plt.title('Volvo Net Profit Margin for Each Year')
plt.show()

# Current Ratios
Volvo_Current_Ratios_2023 = Volvo_sheet2_df.iloc[2, 1] / Volvo_sheet2_df.iloc[23, 1]
Volvo_Current_Ratios_2022 = Volvo_sheet2_df.iloc[2, 2] / Volvo_sheet2_df.iloc[23, 2]
Volvo_Current_Ratios_2021 = Volvo_sheet2_df.iloc[2, 3] / Volvo_sheet2_df.iloc[23, 3]
Volvo_Current_Ratios_2020 = Volvo_sheet2_df.iloc[2, 4] / Volvo_sheet2_df.iloc[23, 4]

Volvo_Current_Ratios = [Volvo_Current_Ratios_2020, Volvo_Current_Ratios_2021, Volvo_Current_Ratios_2022, Volvo_Current_Ratios_2023]
print(Volvo_Current_Ratios)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Volvo_Current_Ratios, marker='o', color='green', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Volvo Current Ratios')
plt.title('Volvo Current Ratios for Each Year')
plt.show()

# Quick Ratios
Volvo_Quick_Ratio_2023 = (Volvo_sheet2_df.iloc[3, 1]+Volvo_sheet2_df.iloc[4, 1])/Volvo_sheet2_df.iloc[23, 1]
Volvo_Quick_Ratio_2022 = (Volvo_sheet2_df.iloc[3, 2]+Volvo_sheet2_df.iloc[4, 2])/Volvo_sheet2_df.iloc[23, 2]
Volvo_Quick_Ratio_2021 = (Volvo_sheet2_df.iloc[3, 3]+Volvo_sheet2_df.iloc[4, 3])/Volvo_sheet2_df.iloc[23, 3]
Volvo_Quick_Ratio_2020 = (Volvo_sheet2_df.iloc[3, 4]+Volvo_sheet2_df.iloc[4, 4])/Volvo_sheet2_df.iloc[23, 4]

Volvo_Quick_Ratio = [Volvo_Quick_Ratio_2020, Volvo_Quick_Ratio_2021, Volvo_Quick_Ratio_2022, Volvo_Quick_Ratio_2023]
print(Volvo_Quick_Ratio)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Volvo_Quick_Ratio, marker='o', color='green', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Volvo Quick Ratio')
plt.title('Volvo Quick Ratio for Each Year')
plt.show()

# Debt to Equity Ratio
Volvo_Debt_To_Equity_Ratio_2023 = Volvo_sheet2_df.iloc[52, 1] / Volvo_sheet2_df.iloc[38, 1]
Volvo_Debt_To_Equity_Ratio_2022 = Volvo_sheet2_df.iloc[52, 2] / Volvo_sheet2_df.iloc[38, 2]
Volvo_Debt_To_Equity_Ratio_2021 = Volvo_sheet2_df.iloc[52, 3] / Volvo_sheet2_df.iloc[38, 3]
Volvo_Debt_To_Equity_Ratio_2020 = Volvo_sheet2_df.iloc[52, 4] / Volvo_sheet2_df.iloc[38, 4]

Volvo_Debt_To_Equity_Ratio = [Volvo_Debt_To_Equity_Ratio_2020, Volvo_Debt_To_Equity_Ratio_2021, Volvo_Debt_To_Equity_Ratio_2022, Volvo_Debt_To_Equity_Ratio_2023]
print(Volvo_Debt_To_Equity_Ratio)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Volvo_Debt_To_Equity_Ratio, marker='o', color='green', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Volvo Debt To Equity Ratio')
plt.title('Volvo Debt To Equity Ratio for Each Year')
plt.show()

# Operating Cash Flow Ratio
Volvo_Operating_Cash_Flow_Ratio_2023 = Volvo_sheet3_df.iloc[1, 1]/Volvo_sheet2_df.iloc[23, 1]
Volvo_Operating_Cash_Flow_Ratio_2022 = Volvo_sheet3_df.iloc[1, 2]/Volvo_sheet2_df.iloc[23, 2]
Volvo_Operating_Cash_Flow_Ratio_2021 = Volvo_sheet3_df.iloc[1, 3]/Volvo_sheet2_df.iloc[23, 3]
Volvo_Operating_Cash_Flow_Ratio_2020 = Volvo_sheet3_df.iloc[1, 4]/Volvo_sheet2_df.iloc[23, 4]

Volvo_Operating_Cash_Flow_Ratio = [Volvo_Operating_Cash_Flow_Ratio_2020, Volvo_Operating_Cash_Flow_Ratio_2021, Volvo_Operating_Cash_Flow_Ratio_2022, Volvo_Operating_Cash_Flow_Ratio_2023]
print(Volvo_Operating_Cash_Flow_Ratio)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Volvo_Operating_Cash_Flow_Ratio, marker='o', color='green', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Volvo Operating Cash Flow Ratio')
plt.title('Volvo Operating Cash Flow Ratio for Each Year')
plt.show()

# Free Cash Flow
Volvo_Free_Cash_Flow_2023 = Volvo_sheet3_df.iloc[1, 1] - Volvo_sheet3_df.iloc[9, 1]
Volvo_Free_Cash_Flow_2022 = Volvo_sheet3_df.iloc[1, 2] - Volvo_sheet3_df.iloc[9, 2]
Volvo_Free_Cash_Flow_2021 = Volvo_sheet3_df.iloc[1, 3] - Volvo_sheet3_df.iloc[9, 3]
Volvo_Free_Cash_Flow_2020 = Volvo_sheet3_df.iloc[1, 4] - Volvo_sheet3_df.iloc[9, 4]

Volvo_Free_Cash_Flow = [Volvo_Free_Cash_Flow_2020, Volvo_Free_Cash_Flow_2021, Volvo_Free_Cash_Flow_2022, Volvo_Free_Cash_Flow_2023]
print(Volvo_Free_Cash_Flow)
plt.figure(figsize=(8,6))
plt.plot(Four_years, Volvo_Free_Cash_Flow, marker='o', color='green', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Volvo Free Cash Flow')
plt.title('Volvo Free Cash Flow for Each Year')
plt.show()
# Out:
# [9.977958078984535, 27.205439852128873, 16.74519883669603]
# [1.7264201674713249, 2.672373030713349, 2.557241187043142, 3.0381862784117635]
# [-2.8316283207310664, -2.3673340807382632, -2.6530048825244945, -2.9144347768386654]
# [-1.4518721442723708, -0.9396825690963504, -1.0999197168791166, -1.1059860819654455]
# [22.481965648854963, 19.799054961452374, 24.887356321839082, 27.293493635077795]
# [-0.3094294610003639, -0.31175124387328706, -0.27234000720909657, -0.22125361844015162]
# [47930000, 55486000, 59090000, 55340000]

# %%
# Revenue Growth Rate
plt.figure(figsize=(10, 6))
plt.plot(Three_years, Porsche_Revenue_Growth_Rate, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(Three_years, Ferrari_Revenue_Growth_Rate, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(Three_years, MercedesBenz_Revenue_Growth_Rate, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(Three_years, Volvo_Revenue_Growth_Rate, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Revenue Growth Rate (%)')
plt.title('Revenue Growth Rate for Each Year')
plt.legend()
plt.show()

# Net Profit Margin
plt.figure(figsize=(10, 6))
plt.plot(Four_years, Porsche_Net_Profit_Margin, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(Four_years, Ferrari_Net_Profit_Margin, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(Four_years, MercedesBenz_Net_Profit_Margin, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(Four_years, Volvo_Net_Profit_Margin, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Net Profit Margin (%)')
plt.title('Net Profit Margin for Each Year')
plt.legend()
plt.show()

# Current Ratios
plt.figure(figsize=(10, 6))
plt.plot(Four_years, Porsche_Current_Ratios, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(Four_years, Ferrari_Current_Ratios, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(Four_years, MercedesBenz_Current_Ratios, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(Four_years, Volvo_Current_Ratios, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Current Ratios')
plt.title('Current Ratios for Each Year')
plt.legend()
plt.show()

# Quick Ratios
plt.figure(figsize=(10, 6))
plt.plot(Four_years, Porsche_Quick_Ratio, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(Four_years, Ferrari_Quick_Ratio, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(Four_years, MercedesBenz_Quick_Ratio, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(Four_years, Volvo_Quick_Ratio, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Quick Ratios')
plt.title('Quick Ratios for Each Year')
plt.legend()
plt.show()

# Debt to Equity Ratios
plt.figure(figsize=(10, 6))
plt.plot(Four_years, Porsche_Debt_To_Equity_Ratio, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(Four_years, Ferrari_Debt_To_Equity_Ratio, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(Four_years, MercedesBenz_Debt_To_Equity_Ratio, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(Four_years, Volvo_Debt_To_Equity_Ratio, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Debt to Equity Ratio')
plt.title('Debt to Equity Ratio for Each Year')
plt.legend()
plt.show()

# Operating Cash Flow Ratios
plt.figure(figsize=(10, 6))
plt.plot(Four_years, Porsche_Operating_Cash_Flow_Ratio, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(Four_years, Ferrari_Operating_Cash_Flow_Ratio, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(Four_years, MercedesBenz_Operating_Cash_Flow_Ratio, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(Four_years, Volvo_Operating_Cash_Flow_Ratio, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Operating Cash Flow Ratio')
plt.title('Operating Cash Flow Ratio for Each Year')
plt.legend()
plt.show()

# Free Cash Flows
plt.figure(figsize=(10, 6))
plt.plot(Four_years, Porsche_Free_Cash_Flow, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(Four_years, Ferrari_Free_Cash_Flow, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(Four_years, MercedesBenz_Free_Cash_Flow, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(Four_years, Volvo_Free_Cash_Flow, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Free Cash Flow')
plt.title('Free Cash Flow for Each Year')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

four_years = [[2020], [2021], [2022], [2023]]
three_years = [[2021], [2022], [2023]]
next_two_years = [[2024], [2025]]

growth_rate_model = LinearRegression()
net_profit_margin_model = LinearRegression()
current_ratios_model = LinearRegression()
quick_ratios_model = LinearRegression()
debt_to_equity_ratios_model = LinearRegression()
operating_cash_flow_ratios_model = LinearRegression()
free_cash_flows_model = LinearRegression()

#Porsche
growth_rate_model.fit(three_years, Porsche_Revenue_Growth_Rate)
net_profit_margin_model.fit(four_years, Porsche_Net_Profit_Margin)
current_ratios_model.fit(four_years, Porsche_Current_Ratios)
quick_ratios_model.fit(four_years, Porsche_Quick_Ratio)
debt_to_equity_ratios_model.fit(four_years, Porsche_Debt_To_Equity_Ratio)
operating_cash_flow_ratios_model.fit(four_years, Porsche_Operating_Cash_Flow_Ratio)
free_cash_flows_model.fit(four_years, Porsche_Free_Cash_Flow)

forecasted_growth_rate = growth_rate_model.predict(next_two_years)
forecasted_net_profit_margin = net_profit_margin_model.predict(next_two_years)
forecasted_current_ratios = current_ratios_model.predict(next_two_years)
forecasted_quick_ratios = quick_ratios_model.predict(next_two_years)
forecasted_debt_to_equity_ratios = debt_to_equity_ratios_model.predict(next_two_years)
forecasted_operating_cash_flow_ratios = operating_cash_flow_ratios_model.predict(next_two_years)
forecasted_free_cash_flows = free_cash_flows_model.predict(next_two_years)

Porsche_Revenue_Growth_Rate.extend(forecasted_growth_rate)
Porsche_Net_Profit_Margin.extend(forecasted_net_profit_margin)
Porsche_Current_Ratios.extend(forecasted_current_ratios)
Porsche_Quick_Ratio.extend(forecasted_quick_ratios)
Porsche_Debt_To_Equity_Ratio.extend(forecasted_debt_to_equity_ratios)
Porsche_Operating_Cash_Flow_Ratio.extend(forecasted_operating_cash_flow_ratios)
Porsche_Free_Cash_Flow.extend(forecasted_free_cash_flows)

# Ferrari
growth_rate_model.fit(three_years, Ferrari_Revenue_Growth_Rate)
net_profit_margin_model.fit(four_years, Ferrari_Net_Profit_Margin)
current_ratios_model.fit(four_years, Ferrari_Current_Ratios)
quick_ratios_model.fit(four_years, Ferrari_Quick_Ratio)
debt_to_equity_ratios_model.fit(four_years, Ferrari_Debt_To_Equity_Ratio)
operating_cash_flow_ratios_model.fit(four_years, Ferrari_Operating_Cash_Flow_Ratio)
free_cash_flows_model.fit(four_years, Ferrari_Free_Cash_Flow)

forecasted_growth_rate = growth_rate_model.predict(next_two_years)
forecasted_net_profit_margin = net_profit_margin_model.predict(next_two_years)
forecasted_current_ratios = current_ratios_model.predict(next_two_years)
forecasted_quick_ratios = quick_ratios_model.predict(next_two_years)
forecasted_debt_to_equity_ratios = debt_to_equity_ratios_model.predict(next_two_years)
forecasted_operating_cash_flow_ratios = operating_cash_flow_ratios_model.predict(next_two_years)
forecasted_free_cash_flows = free_cash_flows_model.predict(next_two_years)

Ferrari_Revenue_Growth_Rate.extend(forecasted_growth_rate)
Ferrari_Net_Profit_Margin.extend(forecasted_net_profit_margin)
Ferrari_Current_Ratios.extend(forecasted_current_ratios)
Ferrari_Quick_Ratio.extend(forecasted_quick_ratios)
Ferrari_Debt_To_Equity_Ratio.extend(forecasted_debt_to_equity_ratios)
Ferrari_Operating_Cash_Flow_Ratio.extend(forecasted_operating_cash_flow_ratios)
Ferrari_Free_Cash_Flow.extend(forecasted_free_cash_flows)


# Mercedes-Benz
growth_rate_model.fit(three_years, MercedesBenz_Revenue_Growth_Rate)
net_profit_margin_model.fit(four_years, MercedesBenz_Net_Profit_Margin)
current_ratios_model.fit(four_years, MercedesBenz_Current_Ratios)
quick_ratios_model.fit(four_years, MercedesBenz_Quick_Ratio)
debt_to_equity_ratios_model.fit(four_years, MercedesBenz_Debt_To_Equity_Ratio)
operating_cash_flow_ratios_model.fit(four_years, MercedesBenz_Operating_Cash_Flow_Ratio)
free_cash_flows_model.fit(four_years, MercedesBenz_Free_Cash_Flow)

forecasted_growth_rate = growth_rate_model.predict(next_two_years)
forecasted_net_profit_margin = net_profit_margin_model.predict(next_two_years)
forecasted_current_ratios = current_ratios_model.predict(next_two_years)
forecasted_quick_ratios = quick_ratios_model.predict(next_two_years)
forecasted_debt_to_equity_ratios = debt_to_equity_ratios_model.predict(next_two_years)
forecasted_operating_cash_flow_ratios = operating_cash_flow_ratios_model.predict(next_two_years)
forecasted_free_cash_flows = free_cash_flows_model.predict(next_two_years)

MercedesBenz_Revenue_Growth_Rate.extend(forecasted_growth_rate)
MercedesBenz_Net_Profit_Margin.extend(forecasted_net_profit_margin)
MercedesBenz_Current_Ratios.extend(forecasted_current_ratios)
MercedesBenz_Quick_Ratio.extend(forecasted_quick_ratios)
MercedesBenz_Debt_To_Equity_Ratio.extend(forecasted_debt_to_equity_ratios)
MercedesBenz_Operating_Cash_Flow_Ratio.extend(forecasted_operating_cash_flow_ratios)
MercedesBenz_Free_Cash_Flow.extend(forecasted_free_cash_flows)

#Volvo
growth_rate_model.fit(three_years, Volvo_Revenue_Growth_Rate)
net_profit_margin_model.fit(four_years, Volvo_Net_Profit_Margin)
current_ratios_model.fit(four_years, Volvo_Current_Ratios)
quick_ratios_model.fit(four_years, Volvo_Quick_Ratio)
debt_to_equity_ratios_model.fit(four_years, Volvo_Debt_To_Equity_Ratio)
operating_cash_flow_ratios_model.fit(four_years, Volvo_Operating_Cash_Flow_Ratio)
free_cash_flows_model.fit(four_years, Volvo_Free_Cash_Flow)

forecasted_growth_rate = growth_rate_model.predict(next_two_years)
forecasted_net_profit_margin = net_profit_margin_model.predict(next_two_years)
forecasted_current_ratios = current_ratios_model.predict(next_two_years)
forecasted_quick_ratios = quick_ratios_model.predict(next_two_years)
forecasted_debt_to_equity_ratios = debt_to_equity_ratios_model.predict(next_two_years)
forecasted_operating_cash_flow_ratios = operating_cash_flow_ratios_model.predict(next_two_years)
forecasted_free_cash_flows = free_cash_flows_model.predict(next_two_years)

Volvo_Revenue_Growth_Rate.extend(forecasted_growth_rate)
Volvo_Net_Profit_Margin.extend(forecasted_net_profit_margin)
Volvo_Current_Ratios.extend(forecasted_current_ratios)
Volvo_Quick_Ratio.extend(forecasted_quick_ratios)
Volvo_Debt_To_Equity_Ratio.extend(forecasted_debt_to_equity_ratios)
Volvo_Operating_Cash_Flow_Ratio.extend(forecasted_operating_cash_flow_ratios)
Volvo_Free_Cash_Flow.extend(forecasted_free_cash_flows)

# %%
five_years = ["2021","2022","2023","2024","2025"]
six_years = ["2020","2021","2022","2023","2024","2025"]

# Revenue Growth Rate
plt.figure(figsize=(10, 6))
plt.plot(five_years, Porsche_Revenue_Growth_Rate, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(five_years, Ferrari_Revenue_Growth_Rate, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(five_years, MercedesBenz_Revenue_Growth_Rate, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(five_years, Volvo_Revenue_Growth_Rate, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Revenue Growth Rate (%)')
plt.title('Revenue Growth Rate for Each Year')
plt.legend()
plt.show()

# Net Profit Margin
plt.figure(figsize=(10, 6))
plt.plot(six_years, Porsche_Net_Profit_Margin, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(six_years, Ferrari_Net_Profit_Margin, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(six_years, MercedesBenz_Net_Profit_Margin, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(six_years, Volvo_Net_Profit_Margin, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Net Profit Margin (%)')
plt.title('Net Profit Margin for Each Year')
plt.legend()
plt.show()

# Current Ratios
plt.figure(figsize=(10, 6))
plt.plot(six_years, Porsche_Current_Ratios, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(six_years, Ferrari_Current_Ratios, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(six_years, MercedesBenz_Current_Ratios, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(six_years, Volvo_Current_Ratios, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Current Ratios')
plt.title('Current Ratios for Each Year')
plt.legend()
plt.show()

# Quick Ratios
plt.figure(figsize=(10, 6))
plt.plot(six_years, Porsche_Quick_Ratio, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(six_years, Ferrari_Quick_Ratio, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(six_years, MercedesBenz_Quick_Ratio, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(six_years, Volvo_Quick_Ratio, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Quick Ratios')
plt.title('Quick Ratios for Each Year')
plt.legend()
plt.show()

# Debt to Equity Ratios
plt.figure(figsize=(10, 6))
plt.plot(six_years, Porsche_Debt_To_Equity_Ratio, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(six_years, Ferrari_Debt_To_Equity_Ratio, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(six_years, MercedesBenz_Debt_To_Equity_Ratio, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(six_years, Volvo_Debt_To_Equity_Ratio, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Debt to Equity Ratio')
plt.title('Debt to Equity Ratio for Each Year')
plt.legend()
plt.show()

# Operating Cash Flow Ratios
plt.figure(figsize=(10, 6))
plt.plot(six_years, Porsche_Operating_Cash_Flow_Ratio, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(six_years, Ferrari_Operating_Cash_Flow_Ratio, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(six_years, MercedesBenz_Operating_Cash_Flow_Ratio, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(six_years, Volvo_Operating_Cash_Flow_Ratio, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Operating Cash Flow Ratio')
plt.title('Operating Cash Flow Ratio for Each Year')
plt.legend()
plt.show()

# Free Cash Flows
plt.figure(figsize=(10, 6))
plt.plot(six_years, Porsche_Free_Cash_Flow, marker='o', color='orange', linestyle='-', label='Porsche')
plt.plot(six_years, Ferrari_Free_Cash_Flow, marker='o', color='red', linestyle='-', label='Ferrari')
plt.plot(six_years, MercedesBenz_Free_Cash_Flow, marker='o', color='blue', linestyle='-', label='Mercedes-Benz')
plt.plot(six_years, Volvo_Free_Cash_Flow, marker='o', color='green', linestyle='-', label='Volvo')
plt.xlabel('Year')
plt.ylabel('Free Cash Flow')
plt.title('Free Cash Flow for Each Year')
plt.legend()
plt.show()

# %%
ESG = [17.1,20.1,25,18.6]
Companies = ["Porsche","Mercedes Benz","Ferrari","Volvo"]
plt.figure(figsize =(8,6))
plt.bar(Companies,ESG,color='skyblue')
plt.xlabel('Companies')
plt.ylabel('ESG Rating')
plt.title('ESG Rating for Each Company')
plt.show()
